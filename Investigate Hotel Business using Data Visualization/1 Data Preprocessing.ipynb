# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## Import dataset and library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/hotel_bookings_data.csv')

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Handling Duplicated Value

# %%
df.duplicated().sum()
# Out:
# 33261

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Handling NULL Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86129 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86129 non-null  object
#  1   is_canceled                     86129 non-null  int64
#  2   lead_time                       86129 non-null  int64
#  3   arrival_date_year               86129 non-null  int64
#  4   arrival_date_month              86129 non-null  object
#  5   arrival_date_week_number        86129 non-null  int64
#  6   arrival_date_day_of_month       86129 non-null  int64
#  7   stays_in_weekend_nights         86129 non-null  int64
#  8   stays_in_weekdays_nights        86129 non-null  int64
#  9   adults                          86129 non-null  int64
#  10  children                        86125 non-null  float64
#  11  babies                          86129 non-null  int64
#  12  meal                            86129 non-null  object
#  13  city                            85679 non-null  object
#  14  market_segment                  86129 non-null  object
#  15  distribution_channel            86129 non-null  object
#  16  is_repeated_guest               86129 non-null  int64
#  17  previous_cancellations          86129 non-null  int64
#  18  previous_bookings_not_canceled  86129 non-null  int64
#  19  booking_changes                 86129 non-null  int64
#  20  deposit_type                    86129 non-null  object
#  21  agent                           74188 non-null  float64
#  22  company                         5110 non-null   float64
#  23  days_in_waiting_list            86129 non-null  int64
#  24  customer_type                   86129 non-null  object
#  25  adr                             86129 non-null  float64
#  26  required_car_parking_spaces     86129 non-null  int64
#  27  total_of_special_requests       86129 non-null  int64
#  28  reservation_status              86129 non-null  object
# dtypes: float64(4), int64(16), object(9)
# memory usage: 19.7+ MB

# %% [markdown]
# Columns that have null values
# - City
# - Agent
# - Company

# %%
df[df.city.isnull()].head()
#City Column, which has a null value, will be ignored because the proportion is small and will be visualized.
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 30    Resort Hotel            0        118               2017
# 4127  Resort Hotel            1          0               2018
# 7092  Resort Hotel            1          8               2018
# 7860  Resort Hotel            1         39               2018
# 8779  Resort Hotel            1          0               2018
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 30            September                        27                          1
# 4127              April                         8                         15
# 7092          September                        30                         21
# 7860            October                        36                         30
# 8779           December                        42                         13
#
#       stays_in_weekend_nights  stays_in_weekdays_nights  adults  children  \
# 30                          4                        10       1       0.0
# 4127                        0                         0       0       0.0
# 7092                        0                         1       1       0.0
# 7860                        0                         5       2       0.0
# 8779                        0                         1       1       0.0
#
#       babies       meal city market_segment distribution_channel  \
# 30         0  Breakfast  NaN         Direct               Direct
# 4127       0    No Meal  NaN  Offline TA/TO                TA/TO
# 7092       0  Breakfast  NaN      Corporate            Corporate
# 7860       0     Dinner  NaN         Direct               Direct
# 8779       0  Breakfast  NaN      Corporate            Corporate
#
#       is_repeated_guest  previous_cancellations  \
# 30                    0                       0
# 4127                  0                       0
# 7092                  0                       0
# 7860                  0                       0
# 8779                  0                       0
#
#       previous_bookings_not_canceled  booking_changes deposit_type  agent  \
# 30                                 0                2   No Deposit    NaN
# 4127                               0                0   No Deposit    NaN
# 7092                               0                0   No Deposit    NaN
# 7860                               0                0   No Deposit    NaN
# 8779                               0                0   No Deposit    NaN
#
#       company  days_in_waiting_list customer_type    adr  \
# 30        NaN                     0      Personal   62.0
# 4127    383.0                     0      Personal    0.0
# 7092    204.0                     0      Personal   73.0
# 7860      NaN                     0      Personal  159.0
# 8779    457.0                     0      Personal   50.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 30                              0                          2
# 4127                            0                          0
# 7092                            0                          2
# 7860                            0                          5
# 8779                            0                          0
#
#      reservation_status
# 30            Check-Out
# 4127           Canceled
# 7092           Canceled
# 7860           Canceled
# 8779           Canceled

# %%
df[df.agent.isnull()].head()
#Agent column, which is null, will be replaced with 0, assuming the hotel booking is not through an agent.
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2017
# 1   Resort Hotel            0        737               2017
# 2   Resort Hotel            0          7               2017
# 6   Resort Hotel            0          0               2017
# 18  Resort Hotel            0          0               2017
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0           September                        27                          1
# 1           September                        27                          1
# 2           September                        27                          1
# 6           September                        27                          1
# 18          September                        27                          1
#
#     stays_in_weekend_nights  stays_in_weekdays_nights  adults  children  \
# 0                         0                         0       2       0.0
# 1                         0                         0       2       0.0
# 2                         0                         1       1       0.0
# 6                         0                         2       2       0.0
# 18                        0                         1       2       0.0
#
#     babies       meal              city market_segment distribution_channel  \
# 0        0  Breakfast     Kota Denpasar         Direct               Direct
# 1        0  Breakfast     Kota Denpasar         Direct               Direct
# 2        0  Breakfast  Kabupaten Bangka         Direct               Direct
# 6        0  Breakfast     Kota Denpasar         Direct               Direct
# 18       0  Breakfast   Kota Yogyakarta      Corporate            Corporate
#
#     is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                   0                       0                               0
# 1                   0                       0                               0
# 2                   0                       0                               0
# 6                   0                       0                               0
# 18                  0                       0                               0
#
#     booking_changes deposit_type  agent  company  days_in_waiting_list  \
# 0                 3   No Deposit    NaN      NaN                     0
# 1                 4   No Deposit    NaN      NaN                     0
# 2                 0   No Deposit    NaN      NaN                     0
# 6                 0   No Deposit    NaN      NaN                     0
# 18                0   No Deposit    NaN    110.0                     0
#
#    customer_type     adr  required_car_parking_spaces  \
# 0       Personal    0.00                            0
# 1       Personal    0.00                            0
# 2       Personal   75.00                            0
# 6       Personal  107.00                            0
# 18      Personal  107.42                            0
#
#     total_of_special_requests reservation_status
# 0                           0          Check-Out
# 1                           0          Check-Out
# 2                           0          Check-Out
# 6                           0          Check-Out
# 18                          0          Check-Out

# %%
df[df.company.isnull()].head()
#The null Company column will be replaced with 0, assuming the hotel booking is not on behalf of the company.
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2017          September
# 1  Resort Hotel            0        737               2017          September
# 2  Resort Hotel            0          7               2017          September
# 3  Resort Hotel            0         13               2017          September
# 4  Resort Hotel            0         14               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_weekdays_nights  adults  children  \
# 0                        0                         0       2       0.0
# 1                        0                         0       2       0.0
# 2                        0                         1       1       0.0
# 3                        0                         1       1       0.0
# 4                        0                         2       2       0.0
#
#    babies       meal              city market_segment distribution_channel  \
# 0       0  Breakfast     Kota Denpasar         Direct               Direct
# 1       0  Breakfast     Kota Denpasar         Direct               Direct
# 2       0  Breakfast  Kabupaten Bangka         Direct               Direct
# 3       0  Breakfast  Kabupaten Bangka      Corporate            Corporate
# 4       0  Breakfast  Kabupaten Bangka      Online TA                TA/TO
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
# 1                  0                       0                               0
# 2                  0                       0                               0
# 3                  0                       0                               0
# 4                  0                       0                               0
#
#    booking_changes deposit_type  agent  company  days_in_waiting_list  \
# 0                3   No Deposit    NaN      NaN                     0
# 1                4   No Deposit    NaN      NaN                     0
# 2                0   No Deposit    NaN      NaN                     0
# 3                0   No Deposit  304.0      NaN                     0
# 4                0   No Deposit  240.0      NaN                     0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0      Personal   0.0                            0                          0
# 1      Personal   0.0                            0                          0
# 2      Personal  75.0                            0                          0
# 3      Personal  75.0                            0                          0
# 4      Personal  98.0                            0                          1
#
#   reservation_status
# 0          Check-Out
# 1          Check-Out
# 2          Check-Out
# 3          Check-Out
# 4          Check-Out

# %%
#Fill Null Values

df['agent'] = df['agent'].fillna(0)
df['company'] = df['company'].fillna(0)

# %% [markdown]
# ## Extract Columns

# %%
# Total Guest = Adults + Childrens + Babies
df['total_guest'] = df['adults'] + df['children'] + df['babies']
df.drop(['adults', 'children', 'babies'], axis=1, inplace=True)

# %% [markdown]
# ## Checking Descriptive Statistics

# %%
#Numeric
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  86129.000000  86129.000000       86129.000000
# mean       0.275587     79.246224        2018.215467
# std        0.446812     85.498774           0.683948
# min        0.000000      0.000000        2017.000000
# 25%        0.000000     11.000000        2018.000000
# 50%        0.000000     49.000000        2018.000000
# 75%        1.000000    124.000000        2019.000000
# max        1.000000    737.000000        2019.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              86129.000000               86129.000000
# mean                  26.796433                  15.806511
# std                   13.675130                   8.840436
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_weekdays_nights  is_repeated_guest  \
# count             86129.000000              86129.000000       86129.000000
# mean                  1.009753                  2.633225           0.039499
# std                   1.033402                  2.058316           0.194780
# min                   0.000000                  0.000000           0.000000
# 25%                   0.000000                  1.000000           0.000000
# 50%                   1.000000                  2.000000           0.000000
# 75%                   2.000000                  4.000000           0.000000
# max                  19.000000                 50.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count            86129.000000                    86129.000000
# mean                 0.030570                        0.186569
# std                  0.371465                        1.744405
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes         agent       company  days_in_waiting_list  \
# count     86129.000000  86129.000000  86129.000000          86129.000000
# mean          0.271987     81.199166     10.800021              0.645114
# std           0.729529    109.964005     53.484435              9.282699
# min           0.000000      0.000000      0.000000              0.000000
# 25%           0.000000      9.000000      0.000000              0.000000
# 50%           0.000000      9.000000      0.000000              0.000000
# 75%           0.000000    240.000000      0.000000              0.000000
# max          21.000000    535.000000    543.000000            391.000000
#
#                 adr  required_car_parking_spaces  total_of_special_requests  \
# count  86129.000000                 86129.000000               86129.000000
# mean     106.634109                     0.085233                   0.705059
# std       55.175319                     0.283070                   0.833525
# min       -6.380000                     0.000000                   0.000000
# 25%       72.250000                     0.000000                   0.000000
# 50%       98.750000                     0.000000                   1.000000
# 75%      134.510000                     0.000000                   1.000000
# max     5400.000000                     8.000000                   5.000000
#
#         total_guest
# count  86125.000000
# mean       2.029806
# std        0.796371
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max       55.000000

# %%
#Average Daily Rate (ADR) has a negative value which may be an input error, so the value is changed to positive.
df[df['adr'] < 0]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 14969  Resort Hotel            0        195               2019
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14969                May                        10                          5
#
#        stays_in_weekend_nights  stays_in_weekdays_nights       meal  \
# 14969                        4                         6  Breakfast
#
#                    city market_segment distribution_channel  \
# 14969  Kabupaten Bangka         Groups               Direct
#
#        is_repeated_guest  previous_cancellations  \
# 14969                  1                       0
#
#        previous_bookings_not_canceled  booking_changes deposit_type  agent  \
# 14969                               2                2   No Deposit  273.0
#
#        company  days_in_waiting_list customer_type   adr  \
# 14969      0.0                     0        Family -6.38
#
#        required_car_parking_spaces  total_of_special_requests  \
# 14969                            0                          0
#
#       reservation_status  total_guest
# 14969          Check-Out          2.0

# %%
df['adr'] = df.adr.replace(-6.38, 6.38)

# %%
#Object
df.describe(include='object')
# Out:
#              hotel arrival_date_month       meal           city  \
# count        86129              86129      86129          85679
# unique           2                 12          5            177
# top     City Hotel            October  Breakfast  Kota Denpasar
# freq         52575              11150      67088          26903
#
#        market_segment distribution_channel deposit_type customer_type  \
# count           86129                86129        86129         86129
# unique              8                    5            3             4
# top         Online TA                TA/TO   No Deposit      Personal
# freq            51393                68141        85024         71648
#
#        reservation_status
# count               86129
# unique                  3
# top             Check-Out
# freq                62393

# %%
categorical = ['hotel','arrival_date_year', 'arrival_date_month', 'meal','city', 'market_segment', 'distribution_channel',
           'deposit_type', 'customer_type', 'reservation_status', 'agent', 'company']

# %%
for i in categorical:
  print(df[i].value_counts())
  print(('*')*100)
# Out:
# City Hotel      52575
# Resort Hotel    33554
# Name: hotel, dtype: int64
# ****************************************************************************************************
# 2018    41841
# 2019    31423
# 2017    12865
# Name: arrival_date_year, dtype: int64
# ****************************************************************************************************
# October      11150
# September     9986
# July          8242
# June          7811
# August        7657
# May           7435
# December      6719
# November      6457
# April         6035
# February      5082
# January       4923
# March         4632
# Name: arrival_date_month, dtype: int64
# ****************************************************************************************************
# Breakfast     67088
# No Meal        9442
# Dinner         8798
# Undefined       454
# Full Board      347
# Name: meal, dtype: int64
# ****************************************************************************************************
# Kota Denpasar              26903
# Kabupaten Bangka           10303
# Kota Yogyakarta             8718
# Kota Batu                   7166
# Kabupaten Bandung           5279
#                            ...
# Kota Bandar Lampung            1
# Kota Cirebon                   1
# Kota Ambon                     1
# Kabupaten Maluku Tengah        1
# Kota Banjarmasin               1
# Name: city, Length: 177, dtype: int64
# ****************************************************************************************************
# Online TA        51393
# Offline TA/TO    13492
# Direct           11740
# Groups            4458
# Corporate         4127
# Complementary      690
# Aviation           227
# Undefined            2
# Name: market_segment, dtype: int64
# ****************************************************************************************************
# TA/TO        68141
# Direct       12850
# Corporate     4955
# GDS            178
# Undefined        5
# Name: distribution_channel, dtype: int64
# ****************************************************************************************************
# No Deposit    85024
# Non Refund     1009
# Refundable       96
# Name: deposit_type, dtype: int64
# ****************************************************************************************************
# Personal     71648
# Family       10814
# Contract      3125
# Bussiness      542
# Name: customer_type, dtype: int64
# ****************************************************************************************************
# Check-Out    62393
# Canceled     22737
# No-Show        999
# Name: reservation_status, dtype: int64
# ****************************************************************************************************
# 9.0      28629
# 240.0    12973
# 0.0      11941
# 14.0      3336
# 7.0       3287
#          ...
# 267.0        1
# 247.0        1
# 278.0        1
# 280.0        1
# 449.0        1
# Name: agent, Length: 334, dtype: int64
# ****************************************************************************************************
# 0.0      81019
# 40.0       847
# 223.0      455
# 45.0       230
# 153.0      206
#          ...
# 54.0         1
# 142.0        1
# 80.0         1
# 11.0         1
# 102.0        1
# Name: company, Length: 353, dtype: int64
# ****************************************************************************************************

# %%
#Rename columns and value

df.rename(columns = {'meal':'meal_type'}, inplace = True)
df['meal_type'] = df['meal_type'].replace('Undefined', 'Lunch')
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2017          September
# 1  Resort Hotel            0        737               2017          September
# 2  Resort Hotel            0          7               2017          September
# 3  Resort Hotel            0         13               2017          September
# 4  Resort Hotel            0         14               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_weekdays_nights  meal_type  \
# 0                        0                         0  Breakfast
# 1                        0                         0  Breakfast
# 2                        0                         1  Breakfast
# 3                        0                         1  Breakfast
# 4                        0                         2  Breakfast
#
#                city market_segment distribution_channel  is_repeated_guest  \
# 0     Kota Denpasar         Direct               Direct                  0
# 1     Kota Denpasar         Direct               Direct                  0
# 2  Kabupaten Bangka         Direct               Direct                  0
# 3  Kabupaten Bangka      Corporate            Corporate                  0
# 4  Kabupaten Bangka      Online TA                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled  booking_changes  \
# 0                       0                               0                3
# 1                       0                               0                4
# 2                       0                               0                0
# 3                       0                               0                0
# 4                       0                               0                0
#
#   deposit_type  agent  company  days_in_waiting_list customer_type   adr  \
# 0   No Deposit    0.0      0.0                     0      Personal   0.0
# 1   No Deposit    0.0      0.0                     0      Personal   0.0
# 2   No Deposit    0.0      0.0                     0      Personal  75.0
# 3   No Deposit  304.0      0.0                     0      Personal  75.0
# 4   No Deposit  240.0      0.0                     0      Personal  98.0
#
#    required_car_parking_spaces  total_of_special_requests reservation_status  \
# 0                            0                          0          Check-Out
# 1                            0                          0          Check-Out
# 2                            0                          0          Check-Out
# 3                            0                          0          Check-Out
# 4                            0                          1          Check-Out
#
#    total_guest
# 0          2.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          2.0

# %%
df.sample(10)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 92548    City Hotel            0        118               2018
# 31312  Resort Hotel            0         71               2018
# 78924    City Hotel            0         26               2017
# 35208  Resort Hotel            0        134               2019
# 45152    City Hotel            1         48               2017
# 59194    City Hotel            1        145               2018
# 53763    City Hotel            1        136               2018
# 18485  Resort Hotel            0          1               2017
# 98549    City Hotel            0         78               2018
# 83949    City Hotel            0          4               2018
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 92548          September                        27                          1
# 31312           February                        52                         21
# 78924           December                        42                         14
# 35208               June                        15                         13
# 45152           December                        43                         19
# 59194           December                        43                         22
# 53763             August                        27                         29
# 18485            January                        47                         16
# 98549           November                        40                         29
# 83949              April                         7                         13
#
#        stays_in_weekend_nights  stays_in_weekdays_nights  meal_type  \
# 92548                        2                         5  Breakfast
# 31312                        0                         2  Breakfast
# 78924                        1                         4  Breakfast
# 35208                        0                         3     Dinner
# 45152                        1                         3  Breakfast
# 59194                        1                         1     Dinner
# 53763                        0                         3    No Meal
# 18485                        1                         4  Breakfast
# 98549                        0                         3  Breakfast
# 83949                        2                         1  Breakfast
#
#                              city market_segment distribution_channel  \
# 92548          Kota Jakarta Pusat      Online TA                TA/TO
# 31312               Kota Denpasar      Online TA                TA/TO
# 78924             Kota Yogyakarta  Offline TA/TO                TA/TO
# 35208               Kota Denpasar  Offline TA/TO                TA/TO
# 45152               Kota Denpasar  Offline TA/TO                TA/TO
# 59194  Kabupaten Kepulauan Seribu      Online TA                TA/TO
# 53763  Kabupaten Kepulauan Seribu      Online TA                TA/TO
# 18485               Kota Surabaya         Direct               Direct
# 98549            Kabupaten Sleman  Offline TA/TO                TA/TO
# 83949               Kota Denpasar      Online TA                TA/TO
#
#        is_repeated_guest  previous_cancellations  \
# 92548                  0                       0
# 31312                  0                       0
# 78924                  0                       0
# 35208                  0                       0
# 45152                  0                       0
# 59194                  0                       0
# 53763                  0                       0
# 18485                  0                       0
# 98549                  0                       0
# 83949                  0                       0
#
#        previous_bookings_not_canceled  booking_changes deposit_type  agent  \
# 92548                               0                0   No Deposit    9.0
# 31312                               0                0   No Deposit  242.0
# 78924                               0                0   No Deposit   28.0
# 35208                               0                2   No Deposit    3.0
# 45152                               0                0   No Deposit   13.0
# 59194                               0                0   No Deposit    9.0
# 53763                               0                0   No Deposit    9.0
# 18485                               0                0   No Deposit    0.0
# 98549                               0                0   No Deposit  138.0
# 83949                               0                0   No Deposit    9.0
#
#        company  days_in_waiting_list customer_type     adr  \
# 92548      0.0                     0        Family  107.95
# 31312      0.0                     0      Personal   37.80
# 78924      0.0                     0      Personal   75.00
# 35208      0.0                     0        Family   79.20
# 45152      0.0                     0        Family   72.36
# 59194      0.0                     0      Personal  153.00
# 53763      0.0                     0      Personal   85.50
# 18485      0.0                     0      Personal   68.00
# 98549      0.0                     0      Personal   95.00
# 83949      0.0                     0      Personal   91.00
#
#        required_car_parking_spaces  total_of_special_requests  \
# 92548                            0                          1
# 31312                            0                          1
# 78924                            0                          0
# 35208                            0                          1
# 45152                            0                          1
# 59194                            0                          0
# 53763                            0                          0
# 18485                            0                          0
# 98549                            0                          1
# 83949                            0                          0
#
#       reservation_status  total_guest
# 92548          Check-Out          2.0
# 31312          Check-Out          2.0
# 78924          Check-Out          2.0
# 35208          Check-Out          2.0
# 45152           Canceled          2.0
# 59194           Canceled          2.0
# 53763           Canceled          2.0
# 18485          Check-Out          2.0
# 98549          Check-Out          2.0
# 83949          Check-Out          2.0
